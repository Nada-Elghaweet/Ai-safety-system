# %% [markdown]
# <a href="https://colab.research.google.com/github/Nada-Elghaweet/Ai-safety-system/blob/mfcc%2BSVC/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, learning_curve
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay, RocCurveDisplay

# %%
def extract_mfcc(file_path, n_mfcc=13):
    y, sr = librosa.load(file_path, sr=None)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    mfcc = np.mean(mfcc, axis=1)
    return mfcc

# %%
violent_path = "/content/drive/MyDrive/violence/violent_audio_preprocessed"
non_violent_path = "/content/drive/MyDrive/non_violence/non_violent_audio_preprocessed"

# %%
print("Total samples:", len(y))
print("Violent:", np.sum(y == 1))
print("Non-violent:", np.sum(y == 0))
# Out:
# Total samples: 2089
# Violent: 904
# Non-violent: 1185

# %%
X = []
y = []

for file in os.listdir(violent_path):
    if file.endswith(".wav"):
        mfcc = extract_mfcc(os.path.join(violent_path, file))
        X.append(mfcc)
        y.append(1)

for file in os.listdir(non_violent_path):
    if file.endswith(".wav"):
        mfcc = extract_mfcc(os.path.join(non_violent_path, file))
        X.append(mfcc)
        y.append(0)

X = np.array(X)
y = np.array(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = SVC(kernel="rbf", C=10, gamma="scale", probability=True)
model.fit(X_train, y_train)
# Out:
# SVC(C=10, probability=True)

# %%
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9976076555023924
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       237
#            1       0.99      1.00      1.00       181
#
#     accuracy                           1.00       418
#    macro avg       1.00      1.00      1.00       418
# weighted avg       1.00      1.00      1.00       418

# %%
def predict_audio_labeled(file_path):
    # 1. Extract features (using your existing function)
    mfcc = extract_mfcc(file_path)

    # 2. Scale features
    mfcc_scaled = scaler.transform([mfcc])

    # 3. Predict class and probability
    prediction = model.predict(mfcc_scaled)[0]
    probabilities = model.predict_proba(mfcc_scaled)[0]

    # 4. Map to labels
    label = "Violence" if prediction == 1 else "Non-Violence"
    confidence = probabilities[prediction] * 100

    print(f"Result: {label} ({confidence:.2f}% confidence)")
    return label

# Usage:
predict_audio_labeled("/content/drive/MyDrive/test2.wav")
# Out:
# Result: Non-Violence (99.99% confidence)
# 'Non-Violence'

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# Plotting the confusion matrix for the test set
fig, ax = plt.subplots(figsize=(8, 6))
disp = ConfusionMatrixDisplay.from_estimator(
    model, X_test, y_test,
    display_labels=["Non-Violence", "Violence"],
    cmap=plt.cm.Blues,
    ax=ax
)
plt.title("Confusion Matrix: Violence Detection")
plt.show()

# %%
from sklearn.model_selection import learning_curve, StratifiedKFold
import matplotlib.pyplot as plt
import numpy as np

# 1. Use StratifiedKFold to ensure both classes are in every split
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 2. Run learning curve
train_sizes, train_scores, test_scores = learning_curve(
    model, X, y,
    cv=cv,
    train_sizes=np.linspace(0.1, 1.0, 5) # Ensure reasonable sizes
)

# 3. Plotting (Now it will work!)
plt.plot(train_sizes, train_scores.mean(axis=1), label="Train")
plt.plot(train_sizes, test_scores.mean(axis=1), label="Validation")
plt.xlabel("Training Size")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
